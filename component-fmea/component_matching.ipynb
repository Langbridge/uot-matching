# %%
import pandas as pd
import matplotlib.pyplot as plt

from ast import literal_eval

# %%
df = pd.read_csv('components_benchmarking_generated_output_v10.2.0_20250814_081818.csv', index_col=0)
df
# Out:
#                                  TypeData.GenCompType  \
# 0                                   Battery - Charger
# 1                                  Bumper - Hydraulic
# 2            Cable - Buried Power - Jacketed - EPR-DR
# 3          Cable - Buried Power - Unjacketed - EPR-DF
# 4   Cable - Plant - 5kV - Black EPR - Jacketed-Non...
# ..                                                ...
# 66                 Transformer - Current - CT - <15kV
# 67                             Transformer - Lighting
# 68    Transformer - Substation with De-Energized DETC
# 69                    Valve - Electro-Hydraulic Servo
# 70  Valve - Steam Turbine - Steam Stop Valve Balan...
#
#                                     failure_locations  \
# 0   ['Capacitors, Electrolytic', 'Capacitors, Oil ...
# 1   ['Bumper Head and Bracket', 'Dust Cover, if pr...
# 2   ['Cable - conductor', 'Cable - insulation', 'C...
# 3   ['Cable - conductor', 'Cable - insulation', 'C...
# ...
